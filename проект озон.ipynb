# %% [markdown]
# У нас есть данные о наиболее частых добавлениях товаров в избранные на Ozon за период с 29.05.2021 по 29.08.2021. Этот период практически полносью охватывает лето 2021 (за вычетом нескольких дней) и поэтому представляет достаточно полную выборку.
#
# Состав данных:
# - название бренда
# - бренд
# - ссылка на товар на Ozon
# - категории товара с 1 по 4 уровень
# - количество добавлений в избранное за последние 30 дней
# - дата последнего появления товара в наличии
#
# Этап работы в Питоне будет включать в себя подготовку данных и первичный статистический анализ. Итоговый вариант данных будет визуализирован в Tableau.

# %% [markdown]
# Импортируем библиотеки, нужные нам для работы, и объединяем нужные нам файлы в один датасет.

# %%
import pandas as pd
import numpy as np

df = pd.concat(map(pd.read_excel, ['chto-dobavlyaut-v-izbrannoe_-29_05_2021-27_06_2021.xlsx', 'chto-dobavlyaut-v-izbrannoe_-26_06_2021-25_07_2021.xlsx', 'chto-dobavlyaut-v-izbrannoe_-31_07_2021-29_08_2021.xlsx']), ignore_index = True)
df.head()
# Out:
#                                      Название товара           Бренд  \
# 0               Игровая консоль PlayStation 5, белый     PlayStation
# 1  La Roche-Posay  Anthelios Fluido Invisible, Фл...  La Roche-Posay
# 2                    Настольная игра GaGa Games Чпок      GAGA Games
# 3  Игровая консоль PlayStation 5 Digital Edition,...     PlayStation
# 4             Barbie Коллекционная кукла BarbieStyle          Barbie
#
#                          Ссылка на товар      Категория 1 уровня  \
# 0  https://www.ozon.ru/product/178337786              ТВ и аудио
# 1  https://www.ozon.ru/product/149766687      Красота и здоровье
# 2  https://www.ozon.ru/product/221133850  Товары для мам и детей
# 3  https://www.ozon.ru/product/207702519              ТВ и аудио
# 4  https://www.ozon.ru/product/265045539  Товары для мам и детей
#
#                         Категория 2 уровня            Категория 3 уровня  \
# 0  Игровые приставки и аксессуары TV&Audio    Игровая приставка TV&Audio
# 1             Косметика для ухода за кожей                         Загар
# 2              Взрослое творчество и хобби  Настольные игры для взрослых
# 3  Игровые приставки и аксессуары TV&Audio    Игровая приставка TV&Audio
# 4                                  Игрушки            Куклы и аксессуары
#
#                              Категория 4 уровня  \
# 0                             Игровая приставка
# 1                       Солнцезащитное средство
# 2  Развлекательная настольная игра для взрослых
# 3                             Игровая приставка
# 4                   Кукла коллекционная детская
#
#    Количество добавлений в избранное, 30 дней Последнее появление в наличии
# 0                                        3576                    2020-12-21
# 1                                        3066                    2021-06-06
# 2                                        2996                    2021-06-12
# 3                                        2528                    2021-04-06
# 4                                        2406                    2021-06-11

# %% [markdown]
# Нам не очень нужна колонка с ссылками на товары, это ненужное загромождение данных. Давайте её удалим.

# %%
df = df.drop(['Ссылка на товар'], axis = 1)

# %%
df.head() # всё нормально удалилось
# Out:
#                                      Название товара           Бренд  \
# 0               Игровая консоль PlayStation 5, белый     PlayStation
# 1  La Roche-Posay  Anthelios Fluido Invisible, Фл...  La Roche-Posay
# 2                    Настольная игра GaGa Games Чпок      GAGA Games
# 3  Игровая консоль PlayStation 5 Digital Edition,...     PlayStation
# 4             Barbie Коллекционная кукла BarbieStyle          Barbie
#
#        Категория 1 уровня                       Категория 2 уровня  \
# 0              ТВ и аудио  Игровые приставки и аксессуары TV&Audio
# 1      Красота и здоровье             Косметика для ухода за кожей
# 2  Товары для мам и детей              Взрослое творчество и хобби
# 3              ТВ и аудио  Игровые приставки и аксессуары TV&Audio
# 4  Товары для мам и детей                                  Игрушки
#
#              Категория 3 уровня                            Категория 4 уровня  \
# 0    Игровая приставка TV&Audio                             Игровая приставка
# 1                         Загар                       Солнцезащитное средство
# 2  Настольные игры для взрослых  Развлекательная настольная игра для взрослых
# 3    Игровая приставка TV&Audio                             Игровая приставка
# 4            Куклы и аксессуары                   Кукла коллекционная детская
#
#    Количество добавлений в избранное, 30 дней Последнее появление в наличии
# 0                                        3576                    2020-12-21
# 1                                        3066                    2021-06-06
# 2                                        2996                    2021-06-12
# 3                                        2528                    2021-04-06
# 4                                        2406                    2021-06-11

# %% [markdown]
# Теперь давайте посмотрим общий список параметров, тип данных каждой колонки (мало ли, надо что-то поменять) и количество пропусков по колонкам.

# %%
df.info()

# по типам данных всё хорошо
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Название товара                             29843 non-null  object
#  1   Бренд                                       28688 non-null  object
#  2   Категория 1 уровня                          30000 non-null  object
#  3   Категория 2 уровня                          30000 non-null  object
#  4   Категория 3 уровня                          30000 non-null  object
#  5   Категория 4 уровня                          30000 non-null  object
#  6   Количество добавлений в избранное, 30 дней  30000 non-null  int64
#  7   Последнее появление в наличии               30000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# Теперь давайте разберёмся с пропусками. Они находятся только в текстовых колонках "Название товара" и "Бренд", поэтому пропуски можно заменить словом "Неизвестно".

# %%
df['Название товара'].fillna(value='Неизвестно', inplace=True)
df['Бренд'].fillna(value='Неизвестно', inplace=True)

# %%
df.isnull().sum()

# пропусков больше нет
# Out:
# Название товара                               0
# Бренд                                         0
# Категория 1 уровня                            0
# Категория 2 уровня                            0
# Категория 3 уровня                            0
# Категория 4 уровня                            0
# Количество добавлений в избранное, 30 дней    0
# Последнее появление в наличии                 0
# dtype: int64

# %% [markdown]
# Теперь посмотрим, есть ли полные дубликаты строк.

# %%
df[df.duplicated()]
# Out:
#                                          Название товара          Бренд  \
# 2219    Чемодан на колесиках пластиковый Lcase, "Ромбик"         L'case
# 5334                                      Платье женское     Технобренд
# 6656                                             Чемодан     Sofiya VIP
# 7768                                         Пижама ТВОЕ           ТВОЕ
# 8753                                         Пижама ТВОЕ           ТВОЕ
# 12352                                      Футболка ТВОЕ           ТВОЕ
# 12623  Детский трикотажный набор: боди без рукавов дл...          Me&We
# 14382                                        Пижама ТВОЕ           ТВОЕ
# 14543                                      Футболка ТВОЕ           ТВОЕ
# 15159                                        Пижама ТВОЕ           ТВОЕ
# 15760                                        Пижама ТВОЕ           ТВОЕ
# 15814  Юбка, майка и трусики для куклы Baby Born рост...      OUBAOLOON
# 16112  Измельчители для соли и перца Russell Hobbs, с...  Russell Hobbs
# 16259                                        Пижама ТВОЕ           ТВОЕ
# 17816                                        Пижама ТВОЕ           ТВОЕ
# 18162                                        Пижама ТВОЕ           ТВОЕ
# 18353                               Комплект трусов ТВОЕ           ТВОЕ
# 18379  Набор для бадминтона WISH   Steeltec 216 (2 ра...           Wish
# 18520                                         Шорты ТВОЕ           ТВОЕ
# 18832  Моторное масло Shell Helix Ultra, синтетическо...          Shell
# 25945              Sapiens. Краткая история человечества     Неизвестно
# 26438                                        Пижама ТВОЕ           ТВОЕ
# 26471                                        Пижама ТВОЕ           ТВОЕ
# 28529                                        Пижама ТВОЕ           ТВОЕ
# 28743                                Ночная рубашка ТВОЕ           ТВОЕ
# 29407                                        Пижама ТВОЕ           ТВОЕ
#
#            Категория 1 уровня               Категория 2 уровня  \
# 2219                   Одежда  Аксессуары для взрослых и детей
# 5334                   Одежда                  Взрослая одежда
# 6656                   Одежда  Аксессуары для взрослых и детей
# 7768                   Одежда                  Взрослая одежда
# 8753                   Одежда                  Взрослая одежда
# 12352                  Одежда                  Взрослая одежда
# 12623                  Одежда                   Детская одежда
# 14382                  Одежда                  Взрослая одежда
# 14543                  Одежда                  Взрослая одежда
# 15159                  Одежда                  Взрослая одежда
# 15760                  Одежда                  Взрослая одежда
# 15814  Товары для мам и детей                          Игрушки
# 16112   Малая бытовая техника       Мелкая бытовая техника SDA
# 16259                  Одежда                  Взрослая одежда
# 17816                  Одежда                  Взрослая одежда
# 18162                  Одежда                  Взрослая одежда
# 18353                  Одежда                  Взрослая одежда
# 18379           Спорт и отдых          Всесезонные виды спорта
# 18520                  Одежда                  Взрослая одежда
# 18832              Автотовары                Масла и автохимия
# 25945                   Книги      Нехудожественная литература
# 26438                  Одежда                  Взрослая одежда
# 26471                  Одежда                  Взрослая одежда
# 28529                  Одежда                  Взрослая одежда
# 28743                  Одежда                  Взрослая одежда
# 29407                  Одежда                  Взрослая одежда
#
#                      Категория 3 уровня  \
# 2219                            Чемодан
# 5334            Основная одежда женская
# 6656                            Чемодан
# 7768            Домашняя одежда женская
# 8753            Домашняя одежда женская
# 12352           Основная одежда женская
# 12623          Одежда для новорожденных
# 14382           Домашняя одежда женская
# 14543           Основная одежда женская
# 15159           Домашняя одежда женская
# 15760           Домашняя одежда женская
# 15814                Куклы и аксессуары
# 16112  Электронная кухонная техника SDA
# 16259           Домашняя одежда женская
# 17816           Домашняя одежда женская
# 18162           Домашняя одежда женская
# 18353                     Белье женское
# 18379                         Бадминтон
# 18520           Основная одежда женская
# 18832               Масла автомобильные
# 25945      Научно-популярная литература
# 26438           Домашняя одежда женская
# 26471           Домашняя одежда женская
# 28529           Домашняя одежда женская
# 28743           Домашняя одежда женская
# 29407           Домашняя одежда женская
#
#                                   Категория 4 уровня  \
# 2219             Чемодан жесткий (алюминий, пластик)
# 5334                         Платье, сарафан женские
# 6656             Чемодан жесткий (алюминий, пластик)
# 7768                  Пижама, ночная сорочка женская
# 8753                  Пижама, ночная сорочка женская
# 12352                               Футболка женская
# 12623                         Боди для новорожденных
# 14382                 Пижама, ночная сорочка женская
# 14543                               Футболка женская
# 15159                 Пижама, ночная сорочка женская
# 15760                 Пижама, ночная сорочка женская
# 15814                        Одежда, обувь кукольная
# 16112  Овощерезка, терка, измельчитель электрические
# 16259                 Пижама, ночная сорочка женская
# 17816                 Пижама, ночная сорочка женская
# 18162                 Пижама, ночная сорочка женская
# 18353                                  Трусы женские
# 18379                           Набор для бадминтона
# 18520                                  Шорты женские
# 18832                     Автохимия - Масло моторное
# 25945                   Научно-популярная литература
# 26438                 Пижама, ночная сорочка женская
# 26471                 Пижама, ночная сорочка женская
# 28529                 Пижама, ночная сорочка женская
# 28743                 Пижама, ночная сорочка женская
# 29407                 Пижама, ночная сорочка женская
#
#        Количество добавлений в избранное, 30 дней  \
# 2219                                          102
# 5334                                           59
# 6656                                           52
# 7768                                           47
# 8753                                           44
# 12352                                         130
# 12623                                         123
# 14382                                          88
# 14543                                          86
# 15159                                          80
# 15760                                          74
# 15814                                          74
# 16112                                          71
# 16259                                          70
# 17816                                          61
# 18162                                          59
# 18353                                          58
# 18379                                          58
# 18520                                          57
# 18832                                          56
# 25945                                          60
# 26438                                          57
# 26471                                          57
# 28529                                          48
# 28743                                          47
# 29407                                          45
#
#       Последнее появление в наличии
# 2219                     2021-06-09
# 5334                     2021-06-10
# 6656                     2021-06-04
# 7768                     2021-06-05
# 8753                     2021-06-12
# 12352                    2021-07-08
# 12623                    2021-07-09
# 14382                    2021-07-09
# 14543                    2021-07-06
# 15159                    2021-07-07
# 15760                    2021-07-05
# 15814                    2021-06-12
# 16112                    2021-05-20
# 16259                    2021-07-10
# 17816                    2021-07-07
# 18162                    2021-07-06
# 18353                    2021-07-09
# 18379                    2021-06-09
# 18520                    2021-07-10
# 18832                    2021-05-26
# 25945                    2021-04-20
# 26438                    2021-08-11
# 26471                    2021-08-11
# 28529                    2021-08-11
# 28743                    2021-08-08
# 29407                    2021-08-09

# %% [markdown]
# Дубликаты есть, теперь их надо удалить.

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()] # дубликатов больше нет
# Out:
# Empty DataFrame
# Columns: [Название товара, Бренд, Категория 1 уровня, Категория 2 уровня, Категория 3 уровня, Категория 4 уровня, Количество добавлений в избранное, 30 дней, Последнее появление в наличии]
# Index: []

# %% [markdown]
# Теперь давайте посмотрим, есть ли выбросы в колонке "Количество добавлений в избранное, 30 дней" (в других колонках выбросы невозможны из-за типа и смысла данных).

# %%
# транспонируем таблицу, чтобы потом можно было создать новый столец с интерквартильным размахом
df_stat = df[['Количество добавлений в избранное, 30 дней']].describe().T

# столбец с интерквартильным размахом
df_stat['iqr'] = df_stat['75%'] - df_stat['25%']

# определяем нижнюю и верхнюю границу допустимых значений
df_stat['lower_bound'] = df_stat['25%'] - 1.5 * df_stat['iqr']
df_stat['upper_bound'] = df_stat['75%'] + 1.5 * df_stat['iqr']

# создаём дополнительный признак, который показывает, есть ли выбросы по каждой из границ
df_stat['any_outlier_min'] = np.where(df_stat['lower_bound'] - df_stat['min'] > 0, 'yes', 'no')
df_stat['any_outlier_max'] = np.where(df_stat['max'] - df_stat['upper_bound'] > 0, 'yes', 'no')

df_stat
# Out:
#                                               count        mean         std  \
# Количество добавлений в избранное, 30 дней  29974.0  106.544472  152.112592
#
#                                              min   25%   50%    75%     max  \
# Количество добавлений в избранное, 30 дней  40.0  54.0  70.0  109.0  6028.0
#
#                                              iqr  lower_bound  upper_bound  \
# Количество добавлений в избранное, 30 дней  55.0        -28.5        191.5
#
#                                            any_outlier_min any_outlier_max
# Количество добавлений в избранное, 30 дней              no             yes

# %% [markdown]
# Выбросы есть с большей стороны, надо их удалить.

# %%
df.drop(df[df['Количество добавлений в избранное, 30 дней'] > 191.5].index, inplace=True)

# %% [markdown]
# Теперь можно посмотреть базовую статистику.

# %%
df.describe(include='all', datetime_is_numeric=True) # datetime_is_numeric=True - новое изменение pandas
# Out:
#        Название товара       Бренд Категория 1 уровня Категория 2 уровня  \
# count            27197       27197              27197              27197
# unique           23468        6655                 21                147
# top        Пижама ТВОЕ  Нет бренда             Одежда    Взрослая одежда
# freq               162        1796               6199               2414
# mean               NaN         NaN                NaN                NaN
# min                NaN         NaN                NaN                NaN
# 25%                NaN         NaN                NaN                NaN
# 50%                NaN         NaN                NaN                NaN
# 75%                NaN         NaN                NaN                NaN
# max                NaN         NaN                NaN                NaN
# std                NaN         NaN                NaN                NaN
#
#              Категория 3 уровня      Категория 4 уровня  \
# count                     27197                   27197
# unique                      666                    2890
# top     Основная одежда женская  Антистрессовая игрушка
# freq                        994                     336
# mean                        NaN                     NaN
# min                         NaN                     NaN
# 25%                         NaN                     NaN
# 50%                         NaN                     NaN
# 75%                         NaN                     NaN
# max                         NaN                     NaN
# std                         NaN                     NaN
#
#         Количество добавлений в избранное, 30 дней  \
# count                                 27197.000000
# unique                                         NaN
# top                                            NaN
# freq                                           NaN
# mean                                     77.860279
# min                                      40.000000
# 25%                                      53.000000
# 50%                                      66.000000
# 75%                                      93.000000
# max                                     191.000000
# std                                      33.809025
#
#         Последнее появление в наличии
# count                           27197
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2021-07-02 04:23:11.977056512
# min               2020-06-03 00:00:00
# 25%               2021-06-10 00:00:00
# 50%               2021-07-06 00:00:00
# 75%               2021-08-06 00:00:00
# max               2021-08-14 00:00:00
# std                               NaN

# %% [markdown]
# Можно выделить несколько интересных моментов:
# - самые популярные вещи не имеют чёткой аффиляции с брендом
# - в то же время, смотря на популярное название, нельзя исключать вероятности, что аффиляция с брендом отражена в названии
# - самой популярной категорией для добавления в избранное является одежда

# %% [markdown]
# И так, мы подготовили данные и провели первичный анализ. Теперь мы можем выгрузить получившийся датасет в формат csv и загрузить его в Tableau для визуализации.

# %%
df.to_csv('ozon_summer2021.csv', index=False)

# %% [markdown]
# Ссылка на дашборд в Tableau: https://public.tableau.com/views/_17127407217810/-10?:language=en-US&publish=yes&:sid=&:display_count=n&:origin=viz_share_link
